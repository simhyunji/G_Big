# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv('master_data_ver2 (1).csv', encoding='euc-kr', index_col= 'date')
df
# Out:
#              num   mos  mean_temp  min_temp  max_temp  rain  wind   hum  \
# date
# 2015-05-01     1  2783       21.0      15.9      27.2   NaN   2.5  58.8
# 2015-05-02     2  2783       20.7      15.8      26.0   0.5   2.1  64.4
# 2015-05-03     3  2998       18.3      17.1      19.6   3.5   2.1  90.4
# 2015-05-04     4  3392       16.1      12.5      20.1   NaN   4.2  45.9
# 2015-05-05     5  3137       14.2       8.3      19.9   NaN   3.4  37.9
# ...          ...   ...        ...       ...       ...   ...   ...   ...
# 2021-10-27  1284   669       13.4       9.8      18.1   0.0   2.2  63.4
# 2021-10-28  1285   691       12.7       7.1      20.0   NaN   1.4  54.6
# 2021-10-29  1286   765       14.6      10.5      20.6   NaN   2.0  55.9
# 2021-10-30  1287   829       13.8      11.0      18.0   NaN   1.6  62.4
# 2021-10-31  1288   745       14.1       9.2      20.3   0.7   1.6  73.3
#
#                atm   sun  cloud  g_temp  b_eva  s_eva
# date
# ...

# %%
df['rain'] = df['rain'].fillna(0) #rain의 결측값을 0으로 변경

# %%
df = df.dropna(axis=0)

# %%
del2 = df[df['mos'].str.isnumeric() == 0].index #숫자가 아닌 행 제거
df = df.drop(del2, inplace = False)
df['mos'].describe()

df['mos'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1227 entries, 2015-05-01 to 2021-10-31
# Series name: mos
# Non-Null Count  Dtype
# --------------  -----
# 1227 non-null   object
# dtypes: object(1)
# memory usage: 19.2+ KB

# %%
df
# Out:
#              num   mos  mean_temp  min_temp  max_temp  rain  wind   hum  \
# date
# 2015-05-01     1  2783       21.0      15.9      27.2   0.0   2.5  58.8
# 2015-05-02     2  2783       20.7      15.8      26.0   0.5   2.1  64.4
# 2015-05-03     3  2998       18.3      17.1      19.6   3.5   2.1  90.4
# 2015-05-04     4  3392       16.1      12.5      20.1   0.0   4.2  45.9
# 2015-05-05     5  3137       14.2       8.3      19.9   0.0   3.4  37.9
# ...          ...   ...        ...       ...       ...   ...   ...   ...
# 2021-10-27  1284   669       13.4       9.8      18.1   0.0   2.2  63.4
# 2021-10-28  1285   691       12.7       7.1      20.0   0.0   1.4  54.6
# 2021-10-29  1286   765       14.6      10.5      20.6   0.0   2.0  55.9
# 2021-10-30  1287   829       13.8      11.0      18.0   0.0   1.6  62.4
# 2021-10-31  1288   745       14.1       9.2      20.3   0.7   1.6  73.3
#
#                atm   sun  cloud  g_temp  b_eva  s_eva
# date
# ...

# %%
df['mos'] = df['mos'].astype('int') #mos를 정수형으로 변경

# %%
df['mos'].max() #mos의 최대값
# Out:
# 26441

# %%
df[df['mos'] ==26441].index
# Out:
# Index(['2016-06-06'], dtype='object', name='date')

# %%
df.corr
# Out:
# <bound method DataFrame.corr of              num   mos  mean_temp  min_temp  max_temp  rain  wind   hum  \
# date
# 2015-05-01     1  2783       21.0      15.9      27.2   0.0   2.5  58.8
# 2015-05-02     2  2783       20.7      15.8      26.0   0.5   2.1  64.4
# 2015-05-03     3  2998       18.3      17.1      19.6   3.5   2.1  90.4
# 2015-05-04     4  3392       16.1      12.5      20.1   0.0   4.2  45.9
# 2015-05-05     5  3137       14.2       8.3      19.9   0.0   3.4  37.9
# ...          ...   ...        ...       ...       ...   ...   ...   ...
# 2021-10-27  1284   669       13.4       9.8      18.1   0.0   2.2  63.4
# 2021-10-28  1285   691       12.7       7.1      20.0   0.0   1.4  54.6
# 2021-10-29  1286   765       14.6      10.5      20.6   0.0   2.0  55.9
# 2021-10-30  1287   829       13.8      11.0      18.0   0.0   1.6  62.4
# 2021-10-31  1288   745       14.1       9.2      20.3   0.7   1.6  73.3
#
#                atm   sun  cloud  g_temp  b_eva  s_eva
# date
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = df.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# %matplotlib inline   
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df.nlargest(2, ['mos'])
# Out:
#             num    mos  mean_temp  min_temp  max_temp  rain  wind   hum  \
# date
# 2016-06-06  221  26441       23.3      20.8      28.4   0.0   2.3  49.1
# 2016-10-03  340  19458       22.7      19.6      27.9   6.5   2.7  73.3
#
#                atm   sun  cloud  g_temp  b_eva  s_eva
# date
# 2016-06-06  1002.4  15.6    7.4    28.0    5.2    6.2
# 2016-10-03   999.9  14.5    4.0    23.6    3.1    4.4

# %%
df.drop(['num'], axis=1, inplace=  True)

# %%
df.corr
# Out:
# <bound method DataFrame.corr of              mos  mean_temp  min_temp  max_temp  rain  wind   hum     atm  \
# date
# 2015-05-01  2783       21.0      15.9      27.2   0.0   2.5  58.8  1003.3
# 2015-05-02  2783       20.7      15.8      26.0   0.5   2.1  64.4  1001.7
# 2015-05-03  2998       18.3      17.1      19.6   3.5   2.1  90.4   997.2
# 2015-05-04  3392       16.1      12.5      20.1   0.0   4.2  45.9   998.9
# 2015-05-05  3137       14.2       8.3      19.9   0.0   3.4  37.9  1001.3
# ...          ...        ...       ...       ...   ...   ...   ...     ...
# 2021-10-27   669       13.4       9.8      18.1   0.0   2.2  63.4  1009.2
# 2021-10-28   691       12.7       7.1      20.0   0.0   1.4  54.6  1013.1
# 2021-10-29   765       14.6      10.5      20.6   0.0   2.0  55.9  1014.5
# 2021-10-30   829       13.8      11.0      18.0   0.0   1.6  62.4  1013.5
# 2021-10-31   745       14.1       9.2      20.3   0.7   1.6  73.3  1013.4
#
# ...

# %%
# %matplotlib inline   
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data = df.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# <AxesSubplot:>
